# %% [markdown]
# # Medical Misinformation Data Crawling Report
#
# **Project:** Crawling images, short-form videos, posts related to medical misinformation
# **Author:** Hoanh Anh Huynh, Lam Duc Anh Khoa
# **Date:** December 2025
